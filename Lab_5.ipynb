# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
from sklearn import datasets
iris = datasets.load_iris()
print(iris.filename)
df= pd.read_csv(iris.filename)
df.head(5)
# Out:
# C:\Users\sm1sm\Anaconda3\lib\site-packages\sklearn\datasets\data\iris.csv
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
iris_data = np.genfromtxt('C:\\Users\\sm1sm\\Anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\iris.csv',
                         delimiter=",", skip_header=1)
print(iris_data)
# Out:
# [[5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.  1.4 0.2 0. ]
#  [4.7 3.2 1.3 0.2 0. ]
#  [4.6 3.1 1.5 0.2 0. ]
#  [5.  3.6 1.4 0.2 0. ]
#  [5.4 3.9 1.7 0.4 0. ]
#  [4.6 3.4 1.4 0.3 0. ]
#  [5.  3.4 1.5 0.2 0. ]
#  [4.4 2.9 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [5.4 3.7 1.5 0.2 0. ]
#  [4.8 3.4 1.6 0.2 0. ]
#  [4.8 3.  1.4 0.1 0. ]
#  [4.3 3.  1.1 0.1 0. ]
#  [5.8 4.  1.2 0.2 0. ]
#  [5.7 4.4 1.5 0.4 0. ]
#  [5.4 3.9 1.3 0.4 0. ]
#  [5.1 3.5 1.4 0.3 0. ]
#  [5.7 3.8 1.7 0.3 0. ]
#  [5.1 3.8 1.5 0.3 0. ]
#  [5.4 3.4 1.7 0.2 0. ]
#  [5.1 3.7 1.5 0.4 0. ]
#  [4.6 3.6 1.  0.2 0. ]
#  [5.1 3.3 1.7 0.5 0. ]
#  [4.8 3.4 1.9 0.2 0. ]
#  [5.  3.  1.6 0.2 0. ]
#  [5.  3.4 1.6 0.4 0. ]
#  [5.2 3.5 1.5 0.2 0. ]
#  [5.2 3.4 1.4 0.2 0. ]
#  [4.7 3.2 1.6 0.2 0. ]
#  [4.8 3.1 1.6 0.2 0. ]
#  [5.4 3.4 1.5 0.4 0. ]
#  [5.2 4.1 1.5 0.1 0. ]
#  [5.5 4.2 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.2 0. ]
#  [5.  3.2 1.2 0.2 0. ]
#  [5.5 3.5 1.3 0.2 0. ]
#  [4.9 3.6 1.4 0.1 0. ]
#  [4.4 3.  1.3 0.2 0. ]
#  [5.1 3.4 1.5 0.2 0. ]
# ...

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# <h1>Exercise 1.1</h1>

# %%
pd.read_csv(filepath_or_buffer='C:\\Users\\sm1sm\\Anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\iris.csv').head(5)
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
pd.read_csv(iris.filename, delimiter='.').head(5)
# Out:
#               150,4,setosa,versicolor,virginica
# 5 1,3 5,1 4,0                               2,0
# 4 9,3 0,1 4,0                               2,0
#   7,3 2,1 3,0                               2,0
#   6,3 1,1 5,0                               2,0
# 5 0,3 6,1 4,0                               2,0

# %%
heads = np.array(['Sepal Length(CM)', 'Sepal Width(CM)', 'Petal length(CM)', 'Petal Width(CM)', 'Variety'])
pd.read_csv(iris.filename, names = heads).head(5)
# Out:
#    Sepal Length(CM)  Sepal Width(CM) Petal length(CM) Petal Width(CM)  \
# 0             150.0              4.0           setosa      versicolor
# 1               5.1              3.5              1.4             0.2
# 2               4.9              3.0              1.4             0.2
# 3               4.7              3.2              1.3             0.2
# 4               4.6              3.1              1.5             0.2
#
#      Variety
# 0  virginica
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# Try to set the header parameter = None! Can
# you explain what was happen?
# The header names got removed and it got replaced to 1,2,3,4,5

# %%
pd.read_csv(iris.filename, header=None).head(5)
# Out:
#        0    1       2           3          4
# 0  150.0  4.0  setosa  versicolor  virginica
# 1    5.1  3.5     1.4         0.2          0
# 2    4.9  3.0     1.4         0.2          0
# 3    4.7  3.2     1.3         0.2          0
# 4    4.6  3.1     1.5         0.2          0

# %%
header_names = ['Sepal Length(CM)', 'Sepal Width(CM)', 'Petal Length(CM)', 'Petal Width(CM)', 'Variety']
iris_columns = pd.read_csv(iris.filename, header = 0, names = header_names)
iris_columns.head()
# Out:
#    Sepal Length(CM)  Sepal Width(CM)  Petal Length(CM)  Petal Width(CM)  \
# 0               5.1              3.5               1.4              0.2
# 1               4.9              3.0               1.4              0.2
# 2               4.7              3.2               1.3              0.2
# 3               4.6              3.1               1.5              0.2
# 4               5.0              3.6               1.4              0.2
#
#    Variety
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# How many attributes found in iris data set?
# - 5 Attributes
# which of them is thetarget class?
# - Variety

# %% [markdown]
# <h1>Exercise 1.2</h1>

# %%
df= pd.read_csv(iris.filename).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 150           150 non-null float64
# 4             150 non-null float64
# setosa        150 non-null float64
# versicolor    150 non-null float64
# virginica     150 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# Exercise 1.2: Your observation, Is there any missing values?
# - No.

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df["150"].count())
print(df["4"].count())
print(df["setosa"].count())
print(df["versicolor"].count())
print(df["virginica"].count())
# Out:
# 150
# 150
# 150
# 150
# 150

# %%
df.describe()
# Out:
#               150           4      setosa  versicolor   virginica
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333    1.000000
# std      0.828066    0.435866    1.765298    0.762238    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000

# %%
print(iris_columns["Variety"].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: Variety, dtype: int64

# %%
print(iris_columns.describe())
# Out:
#        Sepal Length(CM)  Sepal Width(CM)  Petal Length(CM)  Petal Width(CM)  \
# count        150.000000       150.000000        150.000000       150.000000
# mean           5.843333         3.057333          3.758000         1.199333
# std            0.828066         0.435866          1.765298         0.762238
# min            4.300000         2.000000          1.000000         0.100000
# 25%            5.100000         2.800000          1.600000         0.300000
# 50%            5.800000         3.000000          4.350000         1.300000
# 75%            6.400000         3.300000          5.100000         1.800000
# max            7.900000         4.400000          6.900000         2.500000
#
#           Variety
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
for ojha, feature in enumerate(list(iris_columns.columns)[:-1]):
    fg = sns.FacetGrid(iris_columns, hue='Variety', height = 5)
    fg.map(sns.distplot, feature).add_legend()
    plt.show()

# %% [markdown]
# <h1>Exercise 2.1</h1>

# %%
sns.boxplot(x = 'Variety', y = 'Petal Length(CM)', data = iris_columns)
plt.show()

# %%
sns.boxplot(x = 'Variety', y = 'Petal Width(CM)', data = iris_columns)
plt.show()

# %%
sns.boxplot(x = 'Variety', y = 'Sepal Length(CM)', data = iris_columns)
plt.show()

# %%
sns.boxplot(x = 'Variety', y = 'Sepal Width(CM)', data = iris_columns)
plt.show()

# %% [markdown]
# <h1>Exercise 2.2</h1>

# %%
sns.violinplot(x='Variety', y='Sepal Length(CM)', data=iris_columns)
plt.show()

# %%
iris_columns.plot(kind='scatter', x = 'Sepal Length(CM)', y = 'Sepal Width(CM)')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris_columns, hue='Variety', height=10)\
   .map(plt.scatter, 'Sepal Length(CM)', 'Sepal Width(CM)')\
   .add_legend()
plt.show()

# %%
sns.set_style('whitegrid')
sns.pairplot(iris_columns, vars = header_names, hue='Variety',
            diag_kind='kde', plot_kws={'alpha':0.6, 'edgecolor':'k'}, size=2)
plt.show()
# Out:
# C:\Users\sm1sm\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\sm1sm\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
